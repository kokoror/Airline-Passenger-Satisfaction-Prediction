# %% [markdown]
# ## Section 1. clean the train and test dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = 25

# %%
train_data = pd.read_csv('data/train.csv', index_col=0)
test_data = pd.read_csv('data/test.csv', index_col=0)

# %%
train_data.shape, test_data.shape
# Out:
# ((103904, 24), (25976, 24))

# %%
train_data.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# 1             1                       1                 1                 5
# 2             5                       5                 4                 3
# 3             2                       2                 2                 5
# 4             5                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied

# %%
# drop the id column as this column has nothing to do with satisfaction
train_data.drop(['id'], axis = 1, inplace = True)
test_data.drop(['id'], axis = 1, inplace = True)

# %%
# total satisfied and disatisfied value counts
train_data['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
#  11  Online boarding                    103904 non-null  int64
#  12  Seat comfort                       103904 non-null  int64
#  13  Inflight entertainment             103904 non-null  int64
#  14  On-board service                   103904 non-null  int64
#  15  Leg room service                   103904 non-null  int64
#  16  Baggage handling                   103904 non-null  int64
#  17  Checkin service                    103904 non-null  int64
#  18  Inflight service                   103904 non-null  int64
#  19  Cleanliness                        103904 non-null  int64
#  20  Departure Delay in Minutes         103904 non-null  int64
#  21  Arrival Delay in Minutes           103594 non-null  float64
#  22  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 19.0+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25976 entries, 0 to 25975
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             25976 non-null  object
#  1   Customer Type                      25976 non-null  object
#  2   Age                                25976 non-null  int64
#  3   Type of Travel                     25976 non-null  object
#  4   Class                              25976 non-null  object
#  5   Flight Distance                    25976 non-null  int64
#  6   Inflight wifi service              25976 non-null  int64
#  7   Departure/Arrival time convenient  25976 non-null  int64
#  8   Ease of Online booking             25976 non-null  int64
#  9   Gate location                      25976 non-null  int64
#  10  Food and drink                     25976 non-null  int64
#  11  Online boarding                    25976 non-null  int64
#  12  Seat comfort                       25976 non-null  int64
#  13  Inflight entertainment             25976 non-null  int64
#  14  On-board service                   25976 non-null  int64
#  15  Leg room service                   25976 non-null  int64
#  16  Baggage handling                   25976 non-null  int64
#  17  Checkin service                    25976 non-null  int64
#  18  Inflight service                   25976 non-null  int64
#  19  Cleanliness                        25976 non-null  int64
#  20  Departure Delay in Minutes         25976 non-null  int64
#  21  Arrival Delay in Minutes           25893 non-null  float64
#  22  satisfaction                       25976 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 4.8+ MB

# %%
# change the attributes' names to snake_case
train_data.rename(columns = {'Gender' : 'gender', 'Customer Type': 'customer_type', 'Age' : 'age', 
                           'Type of Travel': 'travel_type', 'Class': 'class', 
                           'Flight Distance': 'flight_distance', 
                           'Inflight wifi service': 'inflight_wifi',
                           'Departure/Arrival time convenient': 'departure_n_arrival_time_convenient', 
                           'Ease of Online booking' : 'easy_onlinebooking',
                           'Gate location' : 'gate_location', 'Food and drink' : 'food_n_drink', 
                           'Online boarding' : 'online_boarding', 'Seat comfort': 'seat_comfort',
                           'Inflight entertainment' : 'inflight_entertainment', 
                           'On-board service' : 'onboard_service', 
                           'Leg room service' : 'leg_room_service',
                           'Baggage handling' : 'baggage_handling',
                           'Checkin service' : 'checkin_service', 
                           'Inflight service' : 'inflight_service','Cleanliness' : 'cleanliness',
                           'Departure Delay in Minutes': 'departure_delay_minutes', 
                           'Arrival Delay in Minutes' : 'arrival_delay_minutes',
                           'satisfaction' : 'satisfaction'}, inplace= True)
test_data.rename(columns = {'Gender' : 'gender', 'Customer Type': 'customer_type', 'Age' : 'age', 
                           'Type of Travel': 'travel_type', 'Class': 'class', 
                           'Flight Distance': 'flight_distance', 
                           'Inflight wifi service': 'inflight_wifi',
                           'Departure/Arrival time convenient': 'departure_n_arrival_time_convenient', 
                           'Ease of Online booking' : 'easy_onlinebooking',
                           'Gate location' : 'gate_location', 'Food and drink' : 'food_n_drink', 
                           'Online boarding' : 'online_boarding', 'Seat comfort': 'seat_comfort',
                           'Inflight entertainment' : 'inflight_entertainment', 
                           'On-board service' : 'onboard_service', 
                           'Leg room service' : 'leg_room_service',
                           'Baggage handling' : 'baggage_handling',
                           'Checkin service' : 'checkin_service', 
                           'Inflight service' : 'inflight_service','Cleanliness' : 'cleanliness',
                           'Departure Delay in Minutes': 'departure_delay_minutes', 
                           'Arrival Delay in Minutes' : 'arrival_delay_minutes',
                           'satisfaction' : 'satisfaction'}, inplace= True)

# %%
train_data.head()
# Out:
#    gender      customer_type  age      travel_type     class  flight_distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    inflight_wifi  departure_n_arrival_time_convenient  easy_onlinebooking  \
# 0              3                                    4                   3
# 1              3                                    2                   3
# 2              2                                    2                   2
# 3              2                                    5                   5
# 4              3                                    3                   3
#
#    gate_location  food_n_drink  online_boarding  seat_comfort  \
# 0              1             5                3             5
# 1              3             1                3             1
# 2              2             5                5             5
# 3              5             2                2             2
# 4              3             4                5             5
#
#    inflight_entertainment  onboard_service  leg_room_service  \
# 0                       5                4                 3
# 1                       1                1                 5
# 2                       5                4                 3
# 3                       2                2                 5
# 4                       3                3                 4
#
#    baggage_handling  checkin_service  inflight_service  cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    departure_delay_minutes  arrival_delay_minutes             satisfaction
# 0                       25                   18.0  neutral or dissatisfied
# 1                        1                    6.0  neutral or dissatisfied
# 2                        0                    0.0                satisfied
# 3                       11                    9.0  neutral or dissatisfied
# 4                        0                    0.0                satisfied

# %%
# check if any columns in train_data have nan value
train_data.isna().sum()
# Out:
# gender                                   0
# customer_type                            0
# age                                      0
# travel_type                              0
# class                                    0
# flight_distance                          0
# inflight_wifi                            0
# departure_n_arrival_time_convenient      0
# easy_onlinebooking                       0
# gate_location                            0
# food_n_drink                             0
# online_boarding                          0
# seat_comfort                             0
# inflight_entertainment                   0
# onboard_service                          0
# leg_room_service                         0
# baggage_handling                         0
# checkin_service                          0
# inflight_service                         0
# cleanliness                              0
# departure_delay_minutes                  0
# arrival_delay_minutes                  310
# satisfaction                             0
# dtype: int64

# %%
# notice only column 'arrival_delay_minutes' has 310 nan, so delete these entries
train_data.dropna(axis=0, inplace=True)

# %%
# now all entries in train dataset are valid input
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103594 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   gender                               103594 non-null  object
#  1   customer_type                        103594 non-null  object
#  2   age                                  103594 non-null  int64
#  3   travel_type                          103594 non-null  object
#  4   class                                103594 non-null  object
#  5   flight_distance                      103594 non-null  int64
#  6   inflight_wifi                        103594 non-null  int64
#  7   departure_n_arrival_time_convenient  103594 non-null  int64
#  8   easy_onlinebooking                   103594 non-null  int64
#  9   gate_location                        103594 non-null  int64
#  10  food_n_drink                         103594 non-null  int64
#  11  online_boarding                      103594 non-null  int64
#  12  seat_comfort                         103594 non-null  int64
#  13  inflight_entertainment               103594 non-null  int64
#  14  onboard_service                      103594 non-null  int64
#  15  leg_room_service                     103594 non-null  int64
#  16  baggage_handling                     103594 non-null  int64
#  17  checkin_service                      103594 non-null  int64
#  18  inflight_service                     103594 non-null  int64
#  19  cleanliness                          103594 non-null  int64
#  20  departure_delay_minutes              103594 non-null  int64
#  21  arrival_delay_minutes                103594 non-null  float64
#  22  satisfaction                         103594 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 19.0+ MB

# %%
# check if any columns in test_data have nan value
test_data.isna().sum()
# Out:
# gender                                  0
# customer_type                           0
# age                                     0
# travel_type                             0
# class                                   0
# flight_distance                         0
# inflight_wifi                           0
# departure_n_arrival_time_convenient     0
# easy_onlinebooking                      0
# gate_location                           0
# food_n_drink                            0
# online_boarding                         0
# seat_comfort                            0
# inflight_entertainment                  0
# onboard_service                         0
# leg_room_service                        0
# baggage_handling                        0
# checkin_service                         0
# inflight_service                        0
# cleanliness                             0
# departure_delay_minutes                 0
# arrival_delay_minutes                  83
# satisfaction                            0
# dtype: int64

# %%
# notice only column 'arrival_delay_minutes' has 83 nan, so delete these entries
test_data.dropna(axis=0, inplace=True)

# %%
# now all entries in test dataset are valid input
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25893 entries, 0 to 25975
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               25893 non-null  object
#  1   customer_type                        25893 non-null  object
#  2   age                                  25893 non-null  int64
#  3   travel_type                          25893 non-null  object
#  4   class                                25893 non-null  object
#  5   flight_distance                      25893 non-null  int64
#  6   inflight_wifi                        25893 non-null  int64
#  7   departure_n_arrival_time_convenient  25893 non-null  int64
#  8   easy_onlinebooking                   25893 non-null  int64
#  9   gate_location                        25893 non-null  int64
#  10  food_n_drink                         25893 non-null  int64
#  11  online_boarding                      25893 non-null  int64
#  12  seat_comfort                         25893 non-null  int64
#  13  inflight_entertainment               25893 non-null  int64
#  14  onboard_service                      25893 non-null  int64
#  15  leg_room_service                     25893 non-null  int64
#  16  baggage_handling                     25893 non-null  int64
#  17  checkin_service                      25893 non-null  int64
#  18  inflight_service                     25893 non-null  int64
#  19  cleanliness                          25893 non-null  int64
#  20  departure_delay_minutes              25893 non-null  int64
#  21  arrival_delay_minutes                25893 non-null  float64
#  22  satisfaction                         25893 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 4.7+ MB

# %%
# notice in the original dataset there are feature attributes that contain many distinct numerical values
# for example, departure_delay_minutes has 445 distinct values. Same for age, flight_distance...
train_data.departure_delay_minutes.value_counts()
# Out:
# 0      58552
# 1       2939
# 2       2266
# 3       2006
# 4       1845
#        ...
# 465        1
# 933        1
# 357        1
# 420        1
# 447        1
# Name: departure_delay_minutes, Length: 445, dtype: int64

# %%
# To simplfy our decision tree modeling, we convert the numerical values to categorical values 
# Now we have train_data and test_data with valid entries on all attributes
# We will now handle numerical features and convert them into categorical values

# %%
# Test data:
# convert value of attribute departure_delay_minutes from numerical value to categorical value
cut_labels_delay = ['not delayed', 'less than 1hr delayed', '1-3hr delayed', 'more than 3hr delayed']
cut_bins_delay = [-1, 10, 60, 180, np.inf]
train_data['departure_delay_minutes'] = pd.cut(train_data['departure_delay_minutes'], bins=cut_bins_delay, labels=cut_labels_delay)

# convert value of attribute arrival_delay_minutes from numerical value to categorical value
cut_labels_delay = ['not delayed', 'less than 1hr delayed', '1-3hr delayed', 'more than 3hr delayed']
cut_bins = [-1, 10, 60, 180, np.inf]
train_data['arrival_delay_minutes'] = pd.cut(train_data['arrival_delay_minutes'], bins=cut_bins_delay, labels=cut_labels_delay)

# convert value of attribute age from numerical value to categorical value
cut_labels_age = ['children <18', 'young adults 18-35', 'middle-aged adults 36-55', 'older adults > 56']
cut_bins_age = [-1, 18, 36, 56, np.inf]
train_data['age'] = pd.cut(train_data['age'], bins=cut_bins, labels=cut_labels_age)

# convert value of flight distance from numerical value to categorical value
cut_labels_flight_distance = ['short-haul <1500', 'medium-haul 1500-4100', 'long-haul >4100']
cut_bins_flight_distance = [-1, 1500, 4100, np.inf]
train_data['flight_distance'] = pd.cut(train_data['flight_distance'], bins=cut_bins_flight_distance, labels=cut_labels_flight_distance)

# %%
# inflight_wifideparture_n_arrival_time_convenient	easy_onlinebooking	gate_location	food_n_drink	online_boarding	seat_comfort	inflight_entertainment	onboard_service	leg_room_service	baggage_handling	checkin_service	inflight_service	cleanliness

# %%
# convert customer rating from 1-5 to categorical rating 'poor', 'fair', 'good'
rated_items = train_data.columns[6:-3]
cut_labels_rating = ['poor','fair','good']
cut_bins_rating = [-1, 1, 3, 5]

for item in rated_items:
    train_data[item] = pd.cut(train_data[item], bins=cut_bins_rating, labels=cut_labels_rating)

# %%
# now all the attributes in the train_data are categorical
train_data.head()
# Out:
#    gender      customer_type                       age      travel_type  \
# 0    Male     Loyal Customer        young adults 18-35  Personal Travel
# 1    Male  disloyal Customer        young adults 18-35  Business travel
# 2  Female     Loyal Customer        young adults 18-35  Business travel
# 3  Female     Loyal Customer        young adults 18-35  Business travel
# 4    Male     Loyal Customer  middle-aged adults 36-55  Business travel
#
#       class   flight_distance inflight_wifi  \
# 0  Eco Plus  short-haul <1500          fair
# 1  Business  short-haul <1500          fair
# 2  Business  short-haul <1500          fair
# 3  Business  short-haul <1500          fair
# 4  Business  short-haul <1500          fair
#
#   departure_n_arrival_time_convenient easy_onlinebooking gate_location  \
# 0                                good               fair          poor
# 1                                fair               fair          fair
# 2                                fair               fair          fair
# 3                                good               good          good
# 4                                fair               fair          fair
#
#   food_n_drink online_boarding seat_comfort inflight_entertainment  \
# 0         good            fair         good                   good
# 1         poor            fair         poor                   poor
# 2         good            good         good                   good
# 3         fair            fair         fair                   fair
# 4         good            good         good                   fair
#
#   onboard_service leg_room_service baggage_handling checkin_service  \
# 0            good             fair             good            good
# 1            poor             good             fair            poor
# 2            good             fair             good            good
# 3            fair             good             fair            poor
# 4            fair             good             good            fair
#
#   inflight_service cleanliness departure_delay_minutes  arrival_delay_minutes  \
# 0             good        good   less than 1hr delayed  less than 1hr delayed
# 1             good        poor             not delayed            not delayed
# 2             good        good             not delayed            not delayed
# 3             good        fair   less than 1hr delayed            not delayed
# 4             fair        fair             not delayed            not delayed
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied

# %%
# Now we handles the test_data in the same way
# convert value of attribute departure_delay_minutes from numerical value to categorical value
cut_labels_delay = ['not delayed', 'less than 1hr delayed', '1-3hr delayed', 'more than 3hr delayed']
cut_bins_delay = [-1, 10, 60, 180, np.inf]
test_data['departure_delay_minutes'] = pd.cut(test_data['departure_delay_minutes'], bins=cut_bins_delay, labels=cut_labels_delay)

# convert value of attribute arrival_delay_minutes from numerical value to categorical value
cut_labels_delay = ['not delayed', 'less than 1hr delayed', '1-3hr delayed', 'more than 3hr delayed']
cut_bins = [-1, 10, 60, 180, np.inf]
test_data['arrival_delay_minutes'] = pd.cut(test_data['arrival_delay_minutes'], bins=cut_bins_delay, labels=cut_labels_delay)

# convert value of attribute age from numerical value to categorical value
cut_labels_age = ['children <18', 'young adults 18-35', 'middle-aged adults 36-55', 'older adults > 56']
cut_bins_age = [-1, 18, 36, 56, np.inf]
test_data['age'] = pd.cut(test_data['age'], bins=cut_bins, labels=cut_labels_age)

# convert value of flight distance from numerical value to categorical value
cut_labels_flight_distance = ['short-haul <1500', 'medium-haul 1500-4100', 'long-haul >4100']
cut_bins_flight_distance = [-1, 1500, 4100, np.inf]
test_data['flight_distance'] = pd.cut(test_data['flight_distance'], bins=cut_bins_flight_distance, labels=cut_labels_flight_distance)

# convert customer rating from 1-5 to categorical rating 'poor', 'fair', 'good'
rated_items = train_data.columns[6:-3]
cut_labels_rating = ['poor','fair','good']
cut_bins_rating = [-1, 1, 3, 5]

for item in rated_items:
    test_data[item] = pd.cut(test_data[item], bins=cut_bins_rating, labels=cut_labels_rating)

# %%
# now all the attributes in the test_data are categorical
test_data.head()
# Out:
#    gender      customer_type                 age      travel_type     class  \
# 0  Female     Loyal Customer  young adults 18-35  Business travel       Eco
# 1  Female     Loyal Customer  young adults 18-35  Business travel  Business
# 2    Male  disloyal Customer  young adults 18-35  Business travel       Eco
# 3    Male     Loyal Customer  young adults 18-35  Business travel  Business
# 4  Female     Loyal Customer  young adults 18-35  Business travel       Eco
#
#          flight_distance inflight_wifi departure_n_arrival_time_convenient  \
# 0       short-haul <1500          good                                good
# 1  medium-haul 1500-4100          poor                                poor
# 2       short-haul <1500          fair                                poor
# 3  medium-haul 1500-4100          poor                                poor
# 4       short-haul <1500          fair                                fair
#
#   easy_onlinebooking gate_location food_n_drink online_boarding seat_comfort  \
# 0               fair          good         fair            good         fair
# 1               fair          poor         good            good         good
# 2               fair          good         fair            fair         fair
# 3               poor          fair         fair            good         good
# 4               good          fair         good            poor         fair
#
#   inflight_entertainment onboard_service leg_room_service baggage_handling  \
# 0                   good            good             good             good
# 1                   good            good             good             good
# 2                   fair            good             poor             fair
# 3                   poor            poor             poor             poor
# 4                   fair            fair             fair             fair
#
#   checkin_service inflight_service cleanliness departure_delay_minutes  \
# 0            fair             good        good   less than 1hr delayed
# 1            fair             good        good             not delayed
# 2            fair             fair        fair             not delayed
# 3            fair             poor        good             not delayed
# 4            good             fair        good             not delayed
#
#    arrival_delay_minutes             satisfaction
# 0  less than 1hr delayed                satisfied
# 1            not delayed                satisfied
# 2            not delayed  neutral or dissatisfied
# 3            not delayed                satisfied
# 4  less than 1hr delayed                satisfied

# %% [markdown]
# ## Section 2: This section builds helper functions to calculate Entropy value and Information Gain and builds decision tree with helper functions

# %%
def entropy(feature):
    # get all types of entries of the feature and calculate corresponding counts of each type  
    types, counts = np.unique(feature, return_counts=True)
    # calculate the total number of entries of the feature
    numOfEntries = sum(counts)
    # a list used to store the entropy values  
    entroList = []
    sumOfEntropy = 0
    for i in range(len(types)):
        # calculate the proportion of each value 
        proportion = counts[i] / numOfEntries
        # calculate entropy of the value according to the standard entropy equation
        # sum all entropies up to get entropy of the feature
        sumOfEntropy += np.log2(proportion) * (-proportion)

    return sumOfEntropy

# %%
 def informationGain(dataSet, feature, targetFeature):
    # get entropy of the target geature in the given data set
    entropyOfTarget = entropy(dataSet[targetFeature])

    # get all types of entries of the feature and calculate corresponding counts of each type 
    types, counts = np.unique(dataSet[feature], return_counts=True)
    
    # calculate the total number of entries of the feature
    numOfEntries = sum(counts)
    
    sumOfEntropy = 0
    for i in range(len(types)):
        proportion = counts[i]/numOfEntries
        entropyValue = entropy(dataSet[dataSet[feature]==types[i]][targetFeature])
        sumOfEntropy += proportion * entropyValue

    # calculate information gain
    infoGain = entropyOfTarget - sumOfEntropy

    return infoGain

# %%
# now we can try calculating the entropy value of the target feature 'satisfaction'
print("Entropy for the satisfaction dataset:")
entropy(train_data.satisfaction)
# Out:
# Entropy for the satisfaction dataset:
# 0.987161175643557

# %%
# now we calculate the Information Gain at the first level of the tree
# the table list the information gain for all feature attributes in descending order
# we can see that online boarding has the most Information Gain, thus best deliminating the class inpurity 
# therefore, online boarding should be the root node at the decision tree

information_gain_list=[]
for column in train_data.columns:
    information_gain_list.append(informationGain(train_data, column, 'satisfaction'))
information_gain_values=pd.DataFrame(information_gain_list, index=train_data.columns, columns=['IG_value'])
information_gain_values.sort_values(by='IG_value', ascending=False)
# Out:
#                                      IG_value
# satisfaction                         0.987161
# online_boarding                      0.263112
# class                                0.192687
# travel_type                          0.163958
# inflight_wifi                        0.137935
# inflight_entertainment               0.133699
# seat_comfort                         0.110230
# leg_room_service                     0.086912
# onboard_service                      0.077211
# flight_distance                      0.065369
# cleanliness                          0.057948
# easy_onlinebooking                   0.054427
# baggage_handling                     0.052935
# inflight_service                     0.050373
# food_n_drink                         0.037311
# checkin_service                      0.028077
# customer_type                        0.026794
# age                                  0.022904
# arrival_delay_minutes                0.006649
# gate_location                        0.004597
# departure_delay_minutes              0.003575
# departure_n_arrival_time_convenient  0.002631
# gender                               0.000110

# %%
# Now we build the function decision_tree where we recursively find the attribute with the biggest Information Gain
# and save the tree structured attributes in the dictionary

# %%
def decisionTree(dataset, initialDataset, features, targetFeature, majorityClass=None):
    # get all unique classes and counts of the target feature 
    uniqAttrOfTargetFeature, counts = np.unique(dataset[targetFeature], return_counts=True)
    # determine majority class of target feature in the current dataset      
    majorityClass = uniqAttrOfTargetFeature[np.argmax(counts)]
    
    # if target feature only contains one class, return this class
    if len(uniqAttrOfTargetFeature) == 1:
        return uniqAttrOfTargetFeature[0]
    # if there is no feature or no data, return majority class   
    elif len(dataset) == 0 or len(features) == 0:
        return majorityClass    
    # if none of the above are true, build a new branch of the tree:
    else:
        # calculate information gains for each feature
        #choose the feature with the highest gain and use it as spliter
        infogainList = [informationGain(dataset, feature, targetFeature) for feature in features]
        chosenFeature = features[np.argmax(infogainList)]

        # create the initial tree structure 
        tree = {chosenFeature: {}}

        # remove the chosen feature from all features
        # the chosen feature will become the parent node of other features
        features = [item for item in features if item != chosenFeature]
        
        # create nodes under parent node
        parentAttributeValues = np.unique(dataset[chosenFeature])
        for value in parentAttributeValues:
            subDataset = dataset[dataset[chosenFeature] == value]

            # recursively build tree
            subtree = decisionTree(subDataset, initialDataset, features, targetFeature, majorityClass)

            # add subtree to parent tree
            tree[chosenFeature][value] = subtree

        return tree

# %%
feature_attribute_names = train_data.columns[:-1]

# %%
# Save the tree structure in the varible to be used for predicting test dataset
tree = decisionTree(train_data, train_data, feature_attribute_names,'satisfaction', None)

# %%
# root node
tree.keys()
# Out:
# dict_keys(['online_boarding'])

# %%
# second level node
tree['online_boarding']['poor'].keys(), tree['online_boarding']['fair'].keys(), tree['online_boarding']['good'].keys()
# Out:
# (dict_keys(['inflight_wifi']),
#  dict_keys(['inflight_wifi']),
#  dict_keys(['travel_type']))

# %%
tree['online_boarding']['poor']['inflight_wifi']['poor'].keys(), tree['online_boarding']['poor']['inflight_wifi']['fair'].keys(),tree['online_boarding']['poor']['inflight_wifi']['good'].keys()
# Out:
# (dict_keys(['class']), dict_keys(['class']), dict_keys(['travel_type']))

# %%
tree['online_boarding']['poor']['inflight_wifi']['poor'].keys(), tree['online_boarding']['poor']['inflight_wifi']['fair'].keys(),tree['online_boarding']['poor']['inflight_wifi']['good'].keys()
# Out:
# (dict_keys(['class']), dict_keys(['class']), dict_keys(['travel_type']))

# %%
tree['online_boarding']['poor']['inflight_wifi']['poor'].keys(), tree['online_boarding']['poor']['inflight_wifi']['fair'].keys(),tree['online_boarding']['poor']['inflight_wifi']['good'].keys()
# Out:
# (dict_keys(['class']), dict_keys(['class']), dict_keys(['travel_type']))

# %%
tree
# Out:
# {'online_boarding': {'fair': {'inflight_wifi': {'fair': {'travel_type': {'Business travel': {'customer_type': {'Loyal Customer': {'inflight_entertainment': {'fair': {'baggage_handling': {'fair': {'inflight_service': {'fair': {'gate_location': {'fair': {'seat_comfort': {'fair': {'checkin_service': {'fair': {'onboard_service': {'fair': {'gender': {'Female': {'arrival_delay_minutes': {'1-3hr delayed': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied',
#                             'good': {'class': {'Business': 'neutral or dissatisfied',
#                               'Eco': 'satisfied'}}}},
#                           'less than 1hr delayed': 'neutral or dissatisfied',
#                           'more than 3hr delayed': 'neutral or dissatisfied',
#                           'not delayed': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'easy_onlinebooking': {'fair': {'age': {'children <18': 'neutral or dissatisfied',
#                                   'middle-aged adults 36-55': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                                     'good': 'satisfied'}},
#                                   'young adults 18-35': {'flight_distance': {'medium-haul 1500-4100': {'leg_room_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                         'not delayed': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied'}}}}}},
#                                       'good': 'neutral or dissatisfied',
#                                       'poor': 'neutral or dissatisfied'}},
#                                     'short-haul <1500': 'neutral or dissatisfied'}}}},
#                                 'good': 'neutral or dissatisfied',
#                                 'poor': {'class': {'Business': 'neutral or dissatisfied',
#                                   'Eco': 'satisfied'}}}},
#                               'good': {'class': {'Business': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                   'short-haul <1500': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                     'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'leg_room_service': {'fair': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}},
#                                       'good': 'neutral or dissatisfied'}}}}}},
#                                 'Eco': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'leg_room_service': {'fair': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'Eco Plus': 'neutral or dissatisfied'}},
#                               'poor': 'neutral or dissatisfied'}},
#                             'good': {'cleanliness': {'fair': {'class': {'Business': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                   'short-haul <1500': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                     'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                                       'poor': 'neutral or dissatisfied'}}}}}},
#                                 'Eco': 'neutral or dissatisfied'}},
#                               'good': 'neutral or dissatisfied',
#                               'poor': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}}}},
#                         'Male': {'class': {'Business': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                             'good': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                               'good': 'neutral or dissatisfied',
#                               'poor': 'satisfied'}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'Eco': 'neutral or dissatisfied',
#                           'Eco Plus': {'leg_room_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                               'not delayed': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                 'young adults 18-35': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'good': 'neutral or dissatisfied',
#                             'poor': 'neutral or dissatisfied'}}}}}},
#                       'good': {'departure_n_arrival_time_convenient': {'fair': {'food_n_drink': {'fair': {'class': {'Business': {'flight_distance': {'medium-haul 1500-4100': {'gender': {'Female': 'neutral or dissatisfied',
#                                 'Male': {'leg_room_service': {'fair': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                                     'less than 1hr delayed': 'neutral or dissatisfied',
#                                     'not delayed': {'age': {'young adults 18-35': {'easy_onlinebooking': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'good': {'departure_delay_minutes': {'less than 1hr delayed': 'satisfied',
#                                     'not delayed': 'neutral or dissatisfied'}}}}}},
#                               'short-haul <1500': 'neutral or dissatisfied'}},
#                             'Eco': {'leg_room_service': {'fair': {'gender': {'Female': 'neutral or dissatisfied',
#                                 'Male': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                   'not delayed': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                     'not delayed': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'easy_onlinebooking': {'fair': {'cleanliness': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'good': {'gender': {'Female': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                   'short-haul <1500': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                     'not delayed': {'age': {'young adults 18-35': {'easy_onlinebooking': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'Male': 'neutral or dissatisfied'}},
#                               'poor': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                                 'less than 1hr delayed': 'satisfied',
#                                 'not delayed': {'age': {'middle-aged adults 36-55': 'satisfied',
#                                   'young adults 18-35': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                     'short-haul <1500': {'easy_onlinebooking': {'fair': {'gender': {'Male': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}},
#                                       'good': 'neutral or dissatisfied'}}}}}}}}}},
#                             'Eco Plus': 'neutral or dissatisfied'}},
#                           'good': 'satisfied'}},
#                         'good': 'neutral or dissatisfied',
#                         'poor': 'satisfied'}},
#                       'poor': {'gender': {'Female': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                           'less than 1hr delayed': {'departure_delay_minutes': {'1-3hr delayed': 'satisfied',
#                             'less than 1hr delayed': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                               'good': 'neutral or dissatisfied',
#                               'poor': 'satisfied'}},
#                             'not delayed': 'neutral or dissatisfied'}},
#                           'not delayed': {'leg_room_service': {'fair': {'class': {'Business': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                 'short-haul <1500': {'age': {'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'Eco': 'neutral or dissatisfied',
#                               'Eco Plus': 'neutral or dissatisfied'}},
#                             'good': 'neutral or dissatisfied',
#                             'poor': 'neutral or dissatisfied'}}}},
#                         'Male': 'neutral or dissatisfied'}}}},
#                     'good': {'leg_room_service': {'fair': {'departure_delay_minutes': {'1-3hr delayed': {'departure_n_arrival_time_convenient': {'fair': {'gender': {'Female': {'class': {'Business': {'food_n_drink': {'fair': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                   'short-haul <1500': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                     'young adults 18-35': 'satisfied'}}}},
#                                 'good': 'satisfied',
#                                 'poor': 'neutral or dissatisfied'}},
#                               'Eco': 'neutral or dissatisfied',
#                               'Eco Plus': 'neutral or dissatisfied'}},
#                             'Male': 'neutral or dissatisfied'}},
#                           'poor': 'satisfied'}},
#                         'less than 1hr delayed': {'gender': {'Female': 'neutral or dissatisfied',
#                           'Male': {'cleanliness': {'fair': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                               'good': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                 'short-haul <1500': {'age': {'young adults 18-35': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'poor': 'neutral or dissatisfied'}},
#                             'good': {'flight_distance': {'medium-haul 1500-4100': 'satisfied',
#                               'short-haul <1500': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}}}},
#                         'not delayed': {'onboard_service': {'fair': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                             'not delayed': {'gender': {'Female': {'food_n_drink': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                   'young adults 18-35': {'cleanliness': {'fair': {'flight_distance': {'medium-haul 1500-4100': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}},
#                                           'poor': 'neutral or dissatisfied'}},
#                                         'Eco': 'neutral or dissatisfied'}},
#                                       'short-haul <1500': 'neutral or dissatisfied'}},
#                                     'good': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                       'short-haul <1500': {'class': {'Eco': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}}}}}},
#                                     'poor': {'class': {'Business': 'neutral or dissatisfied',
#                                       'Eco': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'good': {'departure_n_arrival_time_convenient': {'fair': {'cleanliness': {'fair': {'class': {'Business': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                         'young adults 18-35': {'flight_distance': {'medium-haul 1500-4100': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}}}},
#                                       'Eco': 'neutral or dissatisfied',
#                                       'Eco Plus': 'neutral or dissatisfied'}},
#                                     'good': {'class': {'Business': 'neutral or dissatisfied',
#                                       'Eco': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}}}},
#                                       'Eco Plus': {'easy_onlinebooking': {'fair': 'satisfied',
#                                         'good': 'neutral or dissatisfied'}}}},
#                                     'poor': {'class': {'Business': 'neutral or dissatisfied',
#                                       'Eco': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                         'short-haul <1500': {'easy_onlinebooking': {'fair': 'satisfied',
#                                           'good': 'neutral or dissatisfied'}}}}}}}},
#                                   'good': 'satisfied'}},
#                                 'poor': {'cleanliness': {'fair': {'class': {'Business': 'neutral or dissatisfied',
#                                     'Eco': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                       'young adults 18-35': {'easy_onlinebooking': {'fair': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied'}}}},
#                                         'good': 'neutral or dissatisfied'}}}},
#                                     'Eco Plus': 'satisfied'}},
#                                   'good': {'flight_distance': {'medium-haul 1500-4100': 'satisfied',
#                                     'short-haul <1500': 'neutral or dissatisfied'}},
#                                   'poor': 'neutral or dissatisfied'}}}},
#                               'Male': {'cleanliness': {'fair': {'flight_distance': {'medium-haul 1500-4100': {'food_n_drink': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                       'young adults 18-35': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}},
#                                         'Eco': 'neutral or dissatisfied'}}}},
#                                     'good': 'neutral or dissatisfied',
#                                     'poor': 'neutral or dissatisfied'}},
#                                   'short-haul <1500': 'neutral or dissatisfied'}},
#                                 'good': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                   'short-haul <1500': {'food_n_drink': {'fair': {'age': {'young adults 18-35': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}}}}}},
#                                     'good': 'neutral or dissatisfied'}}}},
#                                 'poor': {'flight_distance': {'medium-haul 1500-4100': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                                     'good': {'age': {'young adults 18-35': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'short-haul <1500': 'neutral or dissatisfied'}}}}}}}},
#                           'good': {'class': {'Business': {'flight_distance': {'medium-haul 1500-4100': 'satisfied',
#                               'short-haul <1500': {'easy_onlinebooking': {'fair': {'gender': {'Female': 'neutral or dissatisfied',
#                                   'Male': {'age': {'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'good': 'satisfied'}}}},
#                             'Eco': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                               'young adults 18-35': {'gender': {'Female': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'Male': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'Eco Plus': 'neutral or dissatisfied'}},
#                           'poor': 'neutral or dissatisfied'}}}},
#                       'good': {'cleanliness': {'fair': {'food_n_drink': {'fair': {'class': {'Business': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                               'less than 1hr delayed': {'onboard_service': {'fair': {'gender': {'Female': 'neutral or dissatisfied',
#                                   'Male': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                                     'good': 'neutral or dissatisfied'}}}},
#                                 'good': 'satisfied',
#                                 'poor': 'neutral or dissatisfied'}},
#                               'not delayed': {'onboard_service': {'fair': 'neutral or dissatisfied',
#                                 'good': {'gender': {'Female': 'neutral or dissatisfied',
#                                   'Male': {'age': {'children <18': 'neutral or dissatisfied',
#                                     'young adults 18-35': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                       'not delayed': 'satisfied'}}}}}},
#                                 'poor': 'neutral or dissatisfied'}}}},
#                             'Eco': {'onboard_service': {'fair': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'departure_delay_minutes': {'1-3hr delayed': {'gender': {'Male': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied'}}}}}}}},
#                                     'less than 1hr delayed': {'arrival_delay_minutes': {'less than 1hr delayed': {'gender': {'Male': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': 'neutral or dissatisfied'}}}}}},
#                                       'not delayed': 'neutral or dissatisfied'}},
#                                     'not delayed': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                       'not delayed': {'gender': {'Female': {'flight_distance': {'medium-haul 1500-4100': 'satisfied',
#                                           'short-haul <1500': 'neutral or dissatisfied'}},
#                                         'Male': {'age': {'middle-aged adults 36-55': {'flight_distance': {'short-haul <1500': 'neutral or dissatisfied'}},
#                                           'young adults 18-35': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                             'short-haul <1500': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'good': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                                     'not delayed': 'satisfied'}},
#                                   'poor': 'neutral or dissatisfied'}},
#                                 'good': 'satisfied',
#                                 'poor': 'neutral or dissatisfied'}},
#                               'good': 'neutral or dissatisfied',
#                               'poor': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                                 'less than 1hr delayed': 'neutral or dissatisfied',
#                                 'not delayed': {'gender': {'Male': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'Eco Plus': {'gender': {'Female': {'onboard_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                   'not delayed': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'good': 'neutral or dissatisfied',
#                                 'poor': 'neutral or dissatisfied'}},
#                               'Male': 'neutral or dissatisfied'}}}},
#                           'good': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                             'young adults 18-35': {'departure_delay_minutes': {'less than 1hr delayed': 'satisfied',
#                               'not delayed': 'neutral or dissatisfied'}}}},
#                           'poor': 'neutral or dissatisfied'}},
#                         'good': 'satisfied',
#                         'poor': 'neutral or dissatisfied'}},
#                       'poor': {'onboard_service': {'fair': 'neutral or dissatisfied',
#                         'good': {'departure_delay_minutes': {'less than 1hr delayed': {'gender': {'Female': 'satisfied',
#                             'Male': {'age': {'young adults 18-35': {'class': {'Eco': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}},
#                           'not delayed': {'gender': {'Female': 'neutral or dissatisfied',
#                             'Male': {'easy_onlinebooking': {'fair': {'age': {'young adults 18-35': {'class': {'Eco': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'good': 'neutral or dissatisfied'}}}}}},
#                         'poor': {'class': {'Business': {'gender': {'Female': 'satisfied',
#                             'Male': 'neutral or dissatisfied'}},
#                           'Eco': 'neutral or dissatisfied'}}}}}},
#                     'poor': {'departure_n_arrival_time_convenient': {'fair': {'departure_delay_minutes': {'1-3hr delayed': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                           'good': {'onboard_service': {'fair': 'satisfied',
#                             'good': {'class': {'Business': 'satisfied',
#                               'Eco': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'poor': 'neutral or dissatisfied'}},
#                         'less than 1hr delayed': 'neutral or dissatisfied',
#                         'not delayed': {'leg_room_service': {'fair': {'easy_onlinebooking': {'fair': {'flight_distance': {'medium-haul 1500-4100': {'food_n_drink': {'fair': {'gender': {'Female': {'cleanliness': {'fair': {'class': {'Business': {'onboard_service': {'fair': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                           'not delayed': {'age': {'young adults 18-35': 'neutral or dissatisfied'}}}},
#                                         'good': 'neutral or dissatisfied',
#                                         'poor': 'neutral or dissatisfied'}},
#                                       'Eco': 'neutral or dissatisfied',
#                                       'Eco Plus': 'neutral or dissatisfied'}},
#                                     'good': 'neutral or dissatisfied',
#                                     'poor': 'neutral or dissatisfied'}},
#                                   'Male': 'neutral or dissatisfied'}},
#                                 'good': 'neutral or dissatisfied',
#                                 'poor': 'neutral or dissatisfied'}},
#                               'short-haul <1500': 'neutral or dissatisfied'}},
#                             'good': {'arrival_delay_minutes': {'less than 1hr delayed': {'class': {'Business': 'satisfied',
#                                 'Eco': 'neutral or dissatisfied'}},
#                               'not delayed': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'good': 'neutral or dissatisfied',
#                           'poor': {'class': {'Business': 'neutral or dissatisfied',
#                             'Eco': {'onboard_service': {'fair': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                 'short-haul <1500': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                   'not delayed': {'gender': {'Female': {'age': {'young adults 18-35': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': 'neutral or dissatisfied'}}}}}}}},
#                                     'Male': {'age': {'young adults 18-35': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'cleanliness': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'good': 'neutral or dissatisfied',
#                               'poor': 'neutral or dissatisfied'}},
#                             'Eco Plus': 'neutral or dissatisfied'}}}}}},
#                       'good': {'onboard_service': {'fair': {'class': {'Business': 'neutral or dissatisfied',
#                           'Eco': {'gender': {'Female': 'neutral or dissatisfied',
#                             'Male': {'age': {'young adults 18-35': {'flight_distance': {'short-haul <1500': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': {'leg_room_service': {'fair': {'cleanliness': {'fair': {'departure_delay_minutes': {'not delayed': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}}}},
#                         'poor': 'satisfied'}},
#                       'poor': {'onboard_service': {'fair': 'neutral or dissatisfied',
#                         'good': 'satisfied'}}}}}},
#                   'good': {'leg_room_service': {'fair': {'cleanliness': {'fair': {'class': {'Business': {'checkin_service': {'fair': {'departure_n_arrival_time_convenient': {'fair': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                               'less than 1hr delayed': {'flight_distance': {'medium-haul 1500-4100': {'easy_onlinebooking': {'fair': {'arrival_delay_minutes': {'less than 1hr delayed': {'food_n_drink': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                         'young adults 18-35': {'gender': {'Male': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}},
#                                       'good': 'neutral or dissatisfied',
#                                       'poor': 'neutral or dissatisfied'}},
#                                     'not delayed': 'satisfied'}},
#                                   'good': 'satisfied'}},
#                                 'short-haul <1500': 'neutral or dissatisfied'}},
#                               'not delayed': {'food_n_drink': {'fair': {'gender': {'Female': 'neutral or dissatisfied',
#                                   'Male': {'flight_distance': {'medium-haul 1500-4100': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                       'not delayed': {'age': {'young adults 18-35': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}}}},
#                                     'short-haul <1500': 'neutral or dissatisfied'}}}},
#                                 'good': {'gender': {'Female': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                     'short-haul <1500': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                       'young adults 18-35': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'Male': 'neutral or dissatisfied'}},
#                                 'poor': 'neutral or dissatisfied'}}}},
#                             'good': 'satisfied',
#                             'poor': 'neutral or dissatisfied'}},
#                           'good': {'food_n_drink': {'fair': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                               'less than 1hr delayed': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                 'not delayed': 'satisfied'}},
#                               'not delayed': {'arrival_delay_minutes': {'less than 1hr delayed': 'satisfied',
#                                 'not delayed': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                   'young adults 18-35': {'easy_onlinebooking': {'fair': {'gender': {'Female': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                         'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}},
#                                       'Male': {'flight_distance': {'medium-haul 1500-4100': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}}}},
#                                     'good': 'neutral or dissatisfied'}}}}}}}},
#                             'good': {'flight_distance': {'medium-haul 1500-4100': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                 'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                     'not delayed': {'gender': {'Female': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}},
#                                       'Male': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'good': 'neutral or dissatisfied'}}}},
#                               'short-haul <1500': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'poor': 'neutral or dissatisfied'}},
#                         'Eco': {'checkin_service': {'fair': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                             'good': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                               'less than 1hr delayed': 'neutral or dissatisfied',
#                               'not delayed': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                 'young adults 18-35': {'gender': {'Female': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'good': {'food_n_drink': {'fair': 'satisfied',
#                             'good': 'neutral or dissatisfied',
#                             'poor': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                               'poor': 'neutral or dissatisfied'}}}},
#                           'poor': 'neutral or dissatisfied'}},
#                         'Eco Plus': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                           'young adults 18-35': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                 'not delayed': {'checkin_service': {'fair': {'food_n_drink': {'fair': 'satisfied',
#                                     'good': {'gender': {'Female': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'good': 'satisfied',
#                                   'poor': {'gender': {'Female': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'fair': {'food_n_drink': {'good': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'good': 'neutral or dissatisfied'}},
#                             'good': 'neutral or dissatisfied'}}}}}},
#                       'good': {'checkin_service': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                           'young adults 18-35': {'easy_onlinebooking': {'fair': {'class': {'Business': {'departure_delay_minutes': {'1-3hr delayed': {'food_n_drink': {'fair': 'satisfied',
#                                   'poor': 'neutral or dissatisfied'}},
#                                 'less than 1hr delayed': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                                   'less than 1hr delayed': {'gender': {'Female': 'satisfied',
#                                     'Male': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                                       'good': {'flight_distance': {'medium-haul 1500-4100': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}},
#                                       'poor': 'neutral or dissatisfied'}}}},
#                                   'not delayed': 'neutral or dissatisfied'}},
#                                 'not delayed': {'food_n_drink': {'fair': {'gender': {'Female': {'flight_distance': {'medium-haul 1500-4100': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}},
#                                       'short-haul <1500': 'neutral or dissatisfied'}},
#                                     'Male': 'neutral or dissatisfied'}},
#                                   'good': {'flight_distance': {'medium-haul 1500-4100': {'gender': {'Female': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'satisfied'}}}}}},
#                                       'Male': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}},
#                                     'short-haul <1500': 'neutral or dissatisfied'}},
#                                   'poor': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                                     'short-haul <1500': {'gender': {'Female': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'Eco': 'neutral or dissatisfied',
#                               'Eco Plus': 'neutral or dissatisfied'}},
#                             'good': 'satisfied',
#                             'poor': 'neutral or dissatisfied'}}}},
#                         'good': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                           'less than 1hr delayed': {'flight_distance': {'medium-haul 1500-4100': {'class': {'Business': {'food_n_drink': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'satisfied',
#                                   'not delayed': {'gender': {'Female': {'age': {'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'good': {'gender': {'Female': {'age': {'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied'}}}}}}}}}},
#                                   'Male': 'neutral or dissatisfied'}}}},
#                               'Eco': 'neutral or dissatisfied'}},
#                             'short-haul <1500': 'neutral or dissatisfied'}},
#                           'not delayed': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                             'young adults 18-35': {'class': {'Business': {'flight_distance': {'medium-haul 1500-4100': {'gender': {'Female': {'easy_onlinebooking': {'fair': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                                       'good': 'satisfied'}},
#                                     'good': {'food_n_drink': {'fair': 'satisfied',
#                                       'good': 'neutral or dissatisfied'}}}},
#                                   'Male': 'satisfied'}},
#                                 'short-haul <1500': {'gender': {'Female': 'satisfied',
#                                   'Male': 'neutral or dissatisfied'}}}},
#                               'Eco': {'food_n_drink': {'fair': 'satisfied',
#                                 'good': {'departure_delay_minutes': {'less than 1hr delayed': 'satisfied',
#                                   'not delayed': 'neutral or dissatisfied'}},
#                                 'poor': 'neutral or dissatisfied'}},
#                               'Eco Plus': 'satisfied'}}}}}},
#                         'poor': {'departure_delay_minutes': {'1-3hr delayed': 'satisfied',
#                           'less than 1hr delayed': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                             'short-haul <1500': 'satisfied'}},
#                           'not delayed': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                             'good': {'gender': {'Female': {'class': {'Business': {'arrival_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                   'not delayed': {'age': {'young adults 18-35': {'flight_distance': {'medium-haul 1500-4100': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}},
#                                 'Eco': 'neutral or dissatisfied'}},
#                               'Male': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}}}}}},
#                       'poor': {'checkin_service': {'fair': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied',
#                           'poor': 'satisfied'}},
#                         'good': 'neutral or dissatisfied',
#                         'poor': {'flight_distance': {'medium-haul 1500-4100': {'arrival_delay_minutes': {'1-3hr delayed': 'satisfied',
#                             'less than 1hr delayed': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                               'not delayed': 'satisfied'}},
#                             'not delayed': {'departure_delay_minutes': {'less than 1hr delayed': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                 'young adults 18-35': {'gender': {'Female': {'class': {'Business': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'good': {'onboard_service': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}}}},
#                               'not delayed': 'neutral or dissatisfied'}}}},
#                           'short-haul <1500': {'class': {'Business': 'neutral or dissatisfied',
#                             'Eco': 'neutral or dissatisfied',
#                             'Eco Plus': {'gender': {'Female': {'age': {'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': {'easy_onlinebooking': {'fair': {'food_n_drink': {'good': {'onboard_service': {'fair': {'departure_delay_minutes': {'not delayed': {'arrival_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}}}}}}}},
#                     'good': {'class': {'Business': {'checkin_service': {'fair': {'cleanliness': {'fair': 'satisfied',
#                           'good': {'food_n_drink': {'fair': 'satisfied',
#                             'good': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied',
#                               'good': 'satisfied'}}}}}},
#                         'good': 'satisfied',
#                         'poor': {'cleanliness': {'fair': 'neutral or dissatisfied',
#                           'good': 'satisfied'}}}},
#                       'Eco': 'neutral or dissatisfied',
#                       'Eco Plus': 'neutral or dissatisfied'}},
#                     'poor': 'neutral or dissatisfied'}},
#                   'poor': {'cleanliness': {'fair': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                       'less than 1hr delayed': 'neutral or dissatisfied',
#                       'not delayed': {'leg_room_service': {'fair': {'departure_n_arrival_time_convenient': {'fair': {'class': {'Business': {'gender': {'Female': 'neutral or dissatisfied',
#                               'Male': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                 'young adults 18-35': {'food_n_drink': {'fair': 'satisfied',
#                                   'poor': 'neutral or dissatisfied'}}}}}},
#                             'Eco': {'gender': {'Female': 'satisfied',
#                               'Male': 'neutral or dissatisfied'}},
#                             'Eco Plus': 'neutral or dissatisfied'}},
#                           'good': 'satisfied'}},
#                         'good': 'neutral or dissatisfied',
#                         'poor': 'neutral or dissatisfied'}}}},
#                     'good': {'checkin_service': {'fair': {'class': {'Business': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied',
#                           'good': 'satisfied'}},
#                         'Eco': 'satisfied',
#                         'Eco Plus': 'neutral or dissatisfied'}},
#                       'good': 'neutral or dissatisfied',
#                       'poor': {'gender': {'Female': 'satisfied',
#                         'Male': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                           'young adults 18-35': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                             'good': 'neutral or dissatisfied'}}}}}}}},
#                     'poor': {'departure_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                       'less than 1hr delayed': 'neutral or dissatisfied',
#                       'not delayed': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                         'young adults 18-35': {'gender': {'Female': 'satisfied',
#                           'Male': {'flight_distance': {'medium-haul 1500-4100': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied',
#                               'good': 'satisfied'}},
#                             'short-haul <1500': 'satisfied'}}}}}}}}}}}},
#                 'good': {'class': {'Business': 'neutral or dissatisfied',
#                   'Eco': {'cleanliness': {'fair': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#                       'less than 1hr delayed': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied',
#                         'good': {'checkin_service': {'fair': 'neutral or dissatisfied',
#                           'good': {'leg_room_service': {'fair': {'onboard_service': {'fair': {'age': {'middle-aged adults 36-55': {'seat_comfort': {'fair': 'neutral or dissatisfied',
#                                   'good': 'satisfied'}},
#                                 'young adults 18-35': 'neutral or dissatisfied'}},
#                               'good': {'gender': {'Female': 'neutral or dissatisfied',
#                                 'Male': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                   'young adults 18-35': 'satisfied'}}}},
#                               'poor': 'neutral or dissatisfied'}},
#                             'good': 'neutral or dissatisfied',
#                             'poor': 'neutral or dissatisfied'}},
#                           'poor': 'neutral or dissatisfied'}},
#                         'poor': {'gender': {'Female': 'satisfied',
#                           'Male': 'neutral or dissatisfied'}}}},
#                       'more than 3hr delayed': {'easy_onlinebooking': {'fair': 'satisfied',
#                         'good': {'onboard_service': {'fair': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                             'short-haul <1500': 'satisfied'}},
#                           'good': 'neutral or dissatisfied',
#                           'poor': 'neutral or dissatisfied'}}}},
#                       'not delayed': {'seat_comfort': {'fair': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                           'short-haul <1500': {'leg_room_service': {'fair': {'onboard_service': {'fair': {'checkin_service': {'fair': {'gender': {'Female': {'food_n_drink': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                                       'young adults 18-35': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                         'not delayed': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied',
#                                           'good': {'easy_onlinebooking': {'fair': 'neutral or dissatisfied',
#                                             'good': 'neutral or dissatisfied'}}}}}}}},
#                                     'good': 'neutral or dissatisfied',
#                                     'poor': 'neutral or dissatisfied'}},
#                                   'Male': 'neutral or dissatisfied'}},
#                                 'good': 'neutral or dissatisfied',
#                                 'poor': {'gender': {'Female': {'food_n_drink': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
# ...
#                   'Male': 'neutral or dissatisfied'}},
#                 'good': {'gender': {'Female': 'satisfied',
#                   'Male': {'onboard_service': {'fair': 'satisfied',
#                     'poor': 'neutral or dissatisfied'}}}},
#                 'poor': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                   'good': 'satisfied',
#                   'poor': {'baggage_handling': {'fair': 'neutral or dissatisfied',
#                     'good': {'checkin_service': {'fair': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                         'good': {'gender': {'Female': 'satisfied',
#                           'Male': 'neutral or dissatisfied'}},
#                         'poor': 'neutral or dissatisfied'}},
#                       'good': {'onboard_service': {'fair': 'neutral or dissatisfied',
#                         'good': 'neutral or dissatisfied',
#                         'poor': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                           'short-haul <1500': 'satisfied'}}}},
#                       'poor': 'neutral or dissatisfied'}},
#                     'poor': 'neutral or dissatisfied'}}}}}}}},
#             'disloyal Customer': {'gate_location': {'fair': {'baggage_handling': {'fair': {'checkin_service': {'fair': 'neutral or dissatisfied',
#                   'good': {'seat_comfort': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': {'gender': {'Female': 'satisfied',
#                         'Male': 'neutral or dissatisfied'}},
#                       'not delayed': 'neutral or dissatisfied'}},
#                     'good': 'neutral or dissatisfied',
#                     'poor': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                       'poor': 'neutral or dissatisfied'}}}},
#                   'poor': 'neutral or dissatisfied'}},
#                 'good': {'flight_distance': {'medium-haul 1500-4100': {'departure_n_arrival_time_convenient': {'good': 'satisfied',
#                     'poor': 'neutral or dissatisfied'}},
#                   'short-haul <1500': 'neutral or dissatisfied'}},
#                 'poor': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                   'good': 'satisfied',
#                   'poor': 'satisfied'}}}},
#               'good': {'baggage_handling': {'fair': 'neutral or dissatisfied',
#                 'good': {'arrival_delay_minutes': {'1-3hr delayed': 'satisfied',
#                   'less than 1hr delayed': 'neutral or dissatisfied',
#                   'not delayed': {'checkin_service': {'fair': {'onboard_service': {'fair': {'leg_room_service': {'good': 'neutral or dissatisfied',
#                         'poor': 'satisfied'}},
#                       'good': 'satisfied',
#                       'poor': 'neutral or dissatisfied'}},
#                     'good': 'neutral or dissatisfied',
#                     'poor': 'satisfied'}}}},
#                 'poor': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                   'good': 'neutral or dissatisfied',
#                   'poor': {'gender': {'Female': {'leg_room_service': {'fair': 'satisfied',
#                       'poor': 'neutral or dissatisfied'}},
#                     'Male': 'neutral or dissatisfied'}}}}}},
#               'poor': {'leg_room_service': {'fair': {'seat_comfort': {'fair': 'satisfied',
#                   'good': 'satisfied',
#                   'poor': 'neutral or dissatisfied'}},
#                 'good': {'seat_comfort': {'fair': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                     'young adults 18-35': 'satisfied'}},
#                   'good': 'neutral or dissatisfied'}},
#                 'poor': 'neutral or dissatisfied'}}}}}},
#           'Personal Travel': {'arrival_delay_minutes': {'1-3hr delayed': 'neutral or dissatisfied',
#             'less than 1hr delayed': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#               'good': {'food_n_drink': {'fair': 'neutral or dissatisfied',
#                 'good': 'neutral or dissatisfied',
#                 'poor': {'onboard_service': {'fair': {'gender': {'Female': 'satisfied',
#                     'Male': 'neutral or dissatisfied'}},
#                   'good': 'neutral or dissatisfied',
#                   'poor': 'neutral or dissatisfied'}}}},
#               'poor': {'flight_distance': {'medium-haul 1500-4100': 'satisfied',
#                 'short-haul <1500': 'neutral or dissatisfied'}}}},
#             'not delayed': {'inflight_entertainment': {'fair': {'age': {'children <18': 'neutral or dissatisfied',
#                 'middle-aged adults 36-55': 'neutral or dissatisfied',
#                 'young adults 18-35': {'checkin_service': {'fair': {'baggage_handling': {'fair': 'neutral or dissatisfied',
#                     'good': {'gate_location': {'fair': {'onboard_service': {'fair': {'inflight_service': {'fair': 'neutral or dissatisfied',
#                           'good': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                             'not delayed': {'gender': {'Male': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'good': {'food_n_drink': {'fair': {'seat_comfort': {'fair': {'leg_room_service': {'fair': {'cleanliness': {'fair': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}}}},
#                         'good': 'neutral or dissatisfied',
#                         'poor': 'satisfied'}},
#                       'good': 'neutral or dissatisfied',
#                       'poor': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                         'good': {'onboard_service': {'fair': 'satisfied',
#                           'good': {'gender': {'Male': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'good': {'food_n_drink': {'fair': {'seat_comfort': {'fair': {'inflight_service': {'good': {'cleanliness': {'fair': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}},
#                           'poor': 'satisfied'}}}}}},
#                     'poor': 'neutral or dissatisfied'}},
#                   'good': {'gender': {'Female': {'baggage_handling': {'fair': {'departure_n_arrival_time_convenient': {'fair': {'gate_location': {'fair': 'neutral or dissatisfied',
#                           'good': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                             'good': 'satisfied'}}}},
#                         'good': 'neutral or dissatisfied',
#                         'poor': 'satisfied'}},
#                       'good': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                         'good': {'seat_comfort': {'fair': {'gate_location': {'fair': {'leg_room_service': {'fair': 'neutral or dissatisfied',
#                               'good': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'food_n_drink': {'fair': {'onboard_service': {'good': {'inflight_service': {'good': {'cleanliness': {'fair': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'good': {'leg_room_service': {'fair': 'satisfied',
#                               'good': 'neutral or dissatisfied'}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'good': 'neutral or dissatisfied'}},
#                         'poor': 'neutral or dissatisfied'}},
#                       'poor': 'neutral or dissatisfied'}},
#                     'Male': {'departure_n_arrival_time_convenient': {'fair': {'onboard_service': {'fair': 'satisfied',
#                         'good': 'neutral or dissatisfied',
#                         'poor': 'neutral or dissatisfied'}},
#                       'good': 'neutral or dissatisfied',
#                       'poor': 'neutral or dissatisfied'}}}},
#                   'poor': 'neutral or dissatisfied'}}}},
#               'good': {'age': {'children <18': 'neutral or dissatisfied',
#                 'middle-aged adults 36-55': 'neutral or dissatisfied',
#                 'young adults 18-35': {'leg_room_service': {'fair': {'inflight_service': {'fair': 'neutral or dissatisfied',
#                     'good': {'checkin_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': {'flight_distance': {'medium-haul 1500-4100': 'satisfied',
#                           'short-haul <1500': 'neutral or dissatisfied'}},
#                         'not delayed': 'neutral or dissatisfied'}},
#                       'good': {'gate_location': {'fair': {'gender': {'Female': 'neutral or dissatisfied',
#                           'Male': {'seat_comfort': {'good': {'onboard_service': {'fair': 'neutral or dissatisfied',
#                               'good': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied',
#                                 'good': {'baggage_handling': {'fair': 'satisfied',
#                                   'good': {'departure_delay_minutes': {'less than 1hr delayed': 'neutral or dissatisfied',
#                                     'not delayed': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'food_n_drink': {'good': {'cleanliness': {'good': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'poor': 'neutral or dissatisfied'}}}},
#                         'good': 'neutral or dissatisfied',
#                         'poor': {'departure_n_arrival_time_convenient': {'fair': 'satisfied',
#                           'good': {'seat_comfort': {'fair': 'neutral or dissatisfied',
#                             'good': {'gender': {'Female': 'neutral or dissatisfied',
#                               'Male': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'food_n_drink': {'good': {'onboard_service': {'good': {'baggage_handling': {'good': {'cleanliness': {'good': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'poor': 'neutral or dissatisfied'}},
#                           'poor': 'neutral or dissatisfied'}}}},
#                       'poor': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied',
#                         'good': 'satisfied'}}}},
#                     'poor': 'neutral or dissatisfied'}},
#                   'good': {'gate_location': {'fair': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                       'short-haul <1500': {'inflight_service': {'fair': {'baggage_handling': {'fair': {'gender': {'Female': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied',
#                               'poor': 'satisfied'}},
#                             'Male': 'satisfied'}},
#                           'good': 'neutral or dissatisfied',
#                           'poor': 'neutral or dissatisfied'}},
#                         'good': {'gender': {'Female': 'satisfied',
#                           'Male': {'checkin_service': {'fair': {'customer_type': {'Loyal Customer': {'departure_n_arrival_time_convenient': {'good': {'food_n_drink': {'good': {'seat_comfort': {'good': {'onboard_service': {'good': {'baggage_handling': {'good': {'cleanliness': {'good': {'departure_delay_minutes': {'not delayed': 'satisfied'}}}}}}}}}}}}}}}},
#                             'good': {'customer_type': {'Loyal Customer': {'departure_n_arrival_time_convenient': {'good': {'food_n_drink': {'good': {'seat_comfort': {'good': {'onboard_service': {'good': {'baggage_handling': {'good': {'cleanliness': {'good': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}}}},
#                         'poor': 'neutral or dissatisfied'}}}},
#                     'good': {'gender': {'Female': {'baggage_handling': {'fair': 'neutral or dissatisfied',
#                         'good': {'departure_n_arrival_time_convenient': {'good': {'onboard_service': {'fair': 'satisfied',
#                             'good': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'food_n_drink': {'good': {'seat_comfort': {'good': {'checkin_service': {'good': {'inflight_service': {'good': {'cleanliness': {'good': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}},
#                           'poor': 'neutral or dissatisfied'}}}},
#                       'Male': 'neutral or dissatisfied'}},
#                     'poor': 'neutral or dissatisfied'}},
#                   'poor': {'departure_delay_minutes': {'less than 1hr delayed': {'gender': {'Female': 'neutral or dissatisfied',
#                       'Male': 'satisfied'}},
#                     'not delayed': 'neutral or dissatisfied'}}}}}},
#               'poor': {'seat_comfort': {'fair': {'checkin_service': {'fair': 'neutral or dissatisfied',
#                   'good': {'age': {'middle-aged adults 36-55': 'neutral or dissatisfied',
#                     'young adults 18-35': 'satisfied'}},
#                   'poor': 'satisfied'}},
#                 'good': 'satisfied',
#                 'poor': {'leg_room_service': {'fair': {'departure_delay_minutes': {'less than 1hr delayed': {'flight_distance': {'medium-haul 1500-4100': 'neutral or dissatisfied',
#                       'short-haul <1500': 'satisfied'}},
#                     'not delayed': {'age': {'children <18': {'gender': {'Female': 'neutral or dissatisfied',
#                         'Male': {'onboard_service': {'fair': 'neutral or dissatisfied',
#                           'good': 'satisfied'}}}},
#                       'middle-aged adults 36-55': 'neutral or dissatisfied',
#                       'young adults 18-35': 'neutral or dissatisfied'}}}},
#                   'good': {'gate_location': {'fair': {'onboard_service': {'fair': {'departure_n_arrival_time_convenient': {'fair': 'neutral or dissatisfied',
#                         'good': {'gender': {'Female': 'satisfied',
#                           'Male': 'neutral or dissatisfied'}},
#                         'poor': 'satisfied'}},
#                       'good': {'gender': {'Female': 'neutral or dissatisfied',
#                         'Male': {'age': {'children <18': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'good': {'food_n_drink': {'poor': {'baggage_handling': {'good': {'checkin_service': {'good': {'inflight_service': {'good': {'cleanliness': {'poor': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}},
#                           'young adults 18-35': {'checkin_service': {'fair': {'customer_type': {'Loyal Customer': {'flight_distance': {'short-haul <1500': {'departure_n_arrival_time_convenient': {'good': {'food_n_drink': {'poor': {'baggage_handling': {'good': {'inflight_service': {'good': {'cleanliness': {'poor': {'departure_delay_minutes': {'not delayed': 'neutral or dissatisfied'}}}}}}}}}}}}}}}},
#                             'good': 'satisfied'}}}}}},
#                       'poor': 'neutral or dissatisfied'}},
#                     'good': 'neutral or dissatisfied',
#                     'poor': {'departure_n_arrival_time_convenient': {'good': {'gender': {'Female': {'baggage_handling': {'fair': 'neutral or dissatisfied',
#                           'good': 'satisfied'}},
#                         'Male': 'neutral or dissatisfied'}},
#                       'poor': 'satisfied'}}}},
#                   'poor': {'departure_n_arrival_time_convenient': {'fair': {'gate_location': {'fair': 'neutral or dissatisfied',
#                       'good': {'onboard_service': {'fair': 'satisfied',
#                         'poor': 'neutral or dissatisfied'}}}},
#                     'good': {'checkin_service': {'fair': 'satisfied',
#                       'good': 'neutral or dissatisfied',
#                       'poor': 'satisfied'}},
#                     'poor': 'neutral or dissatisfied'}}}}}}}}}}}}}}}}}}}}

# %% [markdown]
# ## Section 3. make prediction. Build predict function

# %%
#prediction making function

#functinon to predict for a single entry
def makePrediction(dataDictionary, tree, default='satisfied'):
    # traverse every feature in dataDictionary - dictionary converted from dataframe
    for feature in list(dataDictionary.keys()):
      # check if tree also has the feature
      if feature in list(tree.keys()):
        try:
            res = tree[feature][dataDictionary[feature]]
        except:
            return default

        res = tree[feature][dataDictionary[feature]]

        # if result is a dictionary, pass it into makePrediction funciton to find the best reult
        if isinstance(res, dict):
            return makePrediction(dataDictionary, res)
        else:
            return res
    
def predict(testDatset):
    # convert test data set into a dictionary
    # since the structure of tree is also a dictionary 
    testDataDic = testDatset.to_dict(orient='records')
    predictions = []

    # make a prediction for all test data sets
    for testData in testDataDic:
        predictions.append(makePrediction(testData, tree, 1.0))

    return predictions

# %%
test_data_without_target=test_data.drop(['satisfaction'], axis=1)
test_data_label = test_data['satisfaction']

# %%
list(test_data_label)
# Out:
# ['satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  ...]

# %%
actual_result = list(test_data_label)

# %%
predict(test_data_without_target)
# Out:
# ['satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  'satisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'neutral or dissatisfied',
#  'satisfied',
#  ...]

# %%
predictied_result = predict(test_data_without_target)

# %% [markdown]
# ## Section 4. evaluate prediction result

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(actual_result, predictied_result)
# Out:
# array([[12943,  1585],
#        [ 1368,  9997]])

# %%
predictied_result.count('neutral or dissatisfied'), predictied_result.count('satisfied')
# Out:
# (14311, 11582)

# %%
actual_result.count('neutral or dissatisfied'), actual_result.count('satisfied')
# Out:
# (14528, 11365)

# %%
result = pd.DataFrame(confusion_matrix(actual_result, predictied_result), columns = [['predicted','predicted'],['neutral or dissatisfied','satisfied']],
             index=[['actual','actual'], ['neutral or dissatisfied', 'satisfied']])
result

# Here is the confusion matrix for our prediction
# Out:
#                                              predicted
#                                neutral or dissatisfied satisfied
# actual neutral or dissatisfied                   12943      1585
#        satisfied                                  1368      9997

# %%
true_positive = result.loc[('actual','satisfied'),('predicted','satisfied')]
false_positive = result.loc[('actual','neutral or dissatisfied'),('predicted','satisfied')]
true_negative = result.loc[('actual','neutral or dissatisfied'),('predicted','neutral or dissatisfied')]
false_negative = result.loc[('actual','satisfied'),('predicted','neutral or dissatisfied')]

# %%
# now we evaluate the accuracy of our prediction
print('precision score:',true_positive/(true_positive + false_positive))
print('recall score:',true_positive/(true_positive + false_negative))
# Out:
# precision score: 0.8631497150751165
# recall score: 0.8796304443466784
